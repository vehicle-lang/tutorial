# %% [markdown]
# # Iris Dataset Classifier Exercise

# %% [markdown]
# ## 1. Generate Model and Data

# %% [markdown]
# ### 1-1. Setup

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import tensorflow as tf
from   tensorflow import keras
import tf2onnx
import idx2numpy
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1-2. Dataset loading & processing

# %%
# load data from scikit-learn library
iris = load_iris()
# onehot coding labels 
label_oneHot = tf.one_hot(iris.target, len(set(iris.target))).numpy()
# split dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(iris.data, label_oneHot, test_size=0.2, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (120, 4) (30, 4) (120, 3) (30, 3)

# %% [markdown]
# ### 1-3. Model building and training

# %%
# 2 hidden layers with relu
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(3)
  ])

# set optimizer, loss function, and evaluation metrics 
model.compile(optimizer='adam',
              loss=keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# model training
model.fit(X_train, y_train, batch_size=1, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 120/120 [==============================] - 2s 5ms/step - loss: 1.1077 - accuracy: 0.2417 - val_loss: 0.9182 - val_accuracy: 0.3667
# Epoch 2/50
# 120/120 [==============================] - 0s 3ms/step - loss: 0.9006 - accuracy: 0.4917 - val_loss: 0.8523 - val_accuracy: 0.6333
# Epoch 3/50
# 120/120 [==============================] - 0s 3ms/step - loss: 0.8462 - accuracy: 0.6500 - val_loss: 0.7932 - val_accuracy: 0.7000
# Epoch 4/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.7767 - accuracy: 0.6583 - val_loss: 0.7276 - val_accuracy: 0.7000
# Epoch 5/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6975 - accuracy: 0.7167 - val_loss: 0.6394 - val_accuracy: 0.7000
# Epoch 6/50
# 120/120 [==============================] - 0s 3ms/step - loss: 0.6138 - accuracy: 0.6833 - val_loss: 0.5586 - val_accuracy: 0.8000
# Epoch 7/50
# 120/120 [==============================] - 0s 3ms/step - loss: 0.5453 - accuracy: 0.7750 - val_loss: 0.5002 - val_accuracy: 0.8000
# Epoch 8/50
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4934 - accuracy: 0.7833 - val_loss: 0.4664 - val_accuracy: 0.9667
# Epoch 9/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.4580 - accuracy: 0.8833 - val_loss: 0.4348 - val_accuracy: 0.9667
# Epoch 10/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.4286 - accuracy: 0.9500 - val_loss: 0.4058 - val_accuracy: 0.9333
# Epoch 11/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.4032 - accuracy: 0.9000 - val_loss: 0.3835 - val_accuracy: 0.9667
# Epoch 12/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.3822 - accuracy: 0.9417 - val_loss: 0.3672 - val_accuracy: 0.9000
# Epoch 13/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.3584 - accuracy: 0.9667 - val_loss: 0.3410 - val_accuracy: 0.9667
# Epoch 14/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.3404 - accuracy: 0.9417 - val_loss: 0.3264 - val_accuracy: 0.9333
# Epoch 15/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.3244 - accuracy: 0.9667 - val_loss: 0.3142 - val_accuracy: 0.9000
# Epoch 16/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.3003 - accuracy: 0.9667 - val_loss: 0.2844 - val_accuracy: 0.9667
# Epoch 17/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.2889 - accuracy: 0.9167 - val_loss: 0.2883 - val_accuracy: 0.9000
# Epoch 18/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.2767 - accuracy: 0.9500 - val_loss: 0.2718 - val_accuracy: 0.9000
# Epoch 19/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.2507 - accuracy: 0.9833 - val_loss: 0.2385 - val_accuracy: 0.9667
# Epoch 20/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.2380 - accuracy: 0.9667 - val_loss: 0.2247 - val_accuracy: 0.9667
# Epoch 21/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.2252 - accuracy: 0.9667 - val_loss: 0.2123 - val_accuracy: 0.9667
# Epoch 22/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.2060 - accuracy: 0.9667 - val_loss: 0.2003 - val_accuracy: 0.9667
# Epoch 23/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1929 - accuracy: 0.9667 - val_loss: 0.1899 - val_accuracy: 0.9667
# Epoch 24/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1867 - accuracy: 0.9750 - val_loss: 0.1961 - val_accuracy: 0.9667
# Epoch 25/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1679 - accuracy: 0.9750 - val_loss: 0.1880 - val_accuracy: 0.9000
# Epoch 26/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1589 - accuracy: 0.9833 - val_loss: 0.1615 - val_accuracy: 0.9667
# Epoch 27/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1523 - accuracy: 0.9750 - val_loss: 0.1645 - val_accuracy: 0.9333
# Epoch 28/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1434 - accuracy: 0.9583 - val_loss: 0.1478 - val_accuracy: 0.9667
# Epoch 29/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1395 - accuracy: 0.9667 - val_loss: 0.1644 - val_accuracy: 0.9000
# Epoch 30/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1316 - accuracy: 0.9750 - val_loss: 0.1398 - val_accuracy: 0.9333
# Epoch 31/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1224 - accuracy: 0.9833 - val_loss: 0.1346 - val_accuracy: 0.9667
# Epoch 32/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1195 - accuracy: 0.9750 - val_loss: 0.1292 - val_accuracy: 0.9667
# Epoch 33/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1153 - accuracy: 0.9667 - val_loss: 0.1492 - val_accuracy: 0.9000
# Epoch 34/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1107 - accuracy: 0.9750 - val_loss: 0.1290 - val_accuracy: 0.9667
# Epoch 35/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1161 - accuracy: 0.9750 - val_loss: 0.1127 - val_accuracy: 0.9667
# Epoch 36/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1017 - accuracy: 0.9917 - val_loss: 0.1124 - val_accuracy: 0.9667
# Epoch 37/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1064 - accuracy: 0.9583 - val_loss: 0.1089 - val_accuracy: 0.9667
# Epoch 38/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0987 - accuracy: 0.9833 - val_loss: 0.1295 - val_accuracy: 0.9333
# Epoch 39/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1075 - accuracy: 0.9500 - val_loss: 0.1196 - val_accuracy: 0.9667
# Epoch 40/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 0.9750 - val_loss: 0.0996 - val_accuracy: 0.9667
# Epoch 41/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0932 - accuracy: 0.9750 - val_loss: 0.0971 - val_accuracy: 0.9667
# Epoch 42/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1000 - accuracy: 0.9667 - val_loss: 0.0957 - val_accuracy: 0.9667
# Epoch 43/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0991 - accuracy: 0.9667 - val_loss: 0.1106 - val_accuracy: 0.9667
# Epoch 44/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0916 - accuracy: 0.9667 - val_loss: 0.1046 - val_accuracy: 0.9667
# Epoch 45/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0940 - accuracy: 0.9583 - val_loss: 0.1050 - val_accuracy: 0.9667
# Epoch 46/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0850 - accuracy: 0.9667 - val_loss: 0.1013 - val_accuracy: 0.9667
# Epoch 47/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0936 - accuracy: 0.9583 - val_loss: 0.0885 - val_accuracy: 0.9667
# Epoch 48/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0888 - accuracy: 0.9833 - val_loss: 0.0874 - val_accuracy: 0.9667
# Epoch 49/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0868 - accuracy: 0.9667 - val_loss: 0.0877 - val_accuracy: 0.9667
# Epoch 50/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0810 - accuracy: 0.9750 - val_loss: 0.0885 - val_accuracy: 0.9667

# %% [markdown]
# ### 1-4. Convert model to onnx, data to idx

# %%
# convert model to onnx
onnx_model, _ = tf2onnx.convert.from_keras(model, output_path="iris_model.onnx")
# convert data to idx
idx2numpy.convert_to_file('iris_test_data.idx', X_test)
idx2numpy.convert_to_file('iris_test_label.idx', y_test)

# %% [markdown]
# ## 2. Explore data (to decide logical specification)

# %% [markdown]
# ### 2-1. Check range of input features

# %%
# get min, max
min_values = np.min(iris.data, axis=0)
max_values = np.max(iris.data, axis=0)
print(min_values, max_values)
# Out:
# [4.3 2.  1.  0.1] [7.9 4.4 6.9 2.5]

# %%
# get mean, std
mean_values = np.mean(iris.data, axis=0)
std_values = np.std(iris.data, axis=0)
print(mean_values, std_values)
# Out:
# [5.84333333 3.05733333 3.758      1.19933333] [0.82530129 0.43441097 1.75940407 0.75969263]

# %% [markdown]
# ### 2-2. Draw scatter plots

# %%
n_features = iris.data.shape[1]

# create subplots for each pair of features
fig, axs = plt.subplots(n_features, n_features, figsize=(16, 8))

# iterate over each pair of features
for i in range(n_features):
    for j in range(n_features):
        # skip diagonal plots 
        if i == j:
            continue    
        ax = axs[i, j]
        scatter = ax.scatter(iris.data[:, i], iris.data[:, j], c=iris.target, label=iris.target_names, alpha=0.5)
        ax.grid(True, linestyle='dotted')
        ax.set_xlabel(iris.feature_names[i], labelpad=0)
        ax.set_ylabel(iris.feature_names[j])
        
# get unique class labels and handles from the scatter plot
handles, labels = scatter.legend_elements()

# Create a single legend for the entire plot
fig.legend(handles, iris.target_names, loc='lower center', ncol=4)

# Adjust subplot spacing
plt.subplots_adjust(wspace=0.3, hspace=0.5)

plt.show()

# %% [markdown]
# ### 2-3. Check relationships between features

# %%
# sepal length is always longer than sepal width
np.any(iris.data[:, 0] - iris.data[:, 1] > 0)
# Out:
# True

# %%
# petal length is always longer than petal width
np.any(iris.data[:, 2] - iris.data[:, 3] > 0)
# Out:
# True

# %% [markdown]
# ### 2-4. Check counter examples

# %%
counter_example =    [4.3, 2.0, 1.236752, 1.236752]
# convert to tensor and reshape
tensor_sample = tf.constant(counter_example, dtype=tf.float32)
tensor_sample = tf.reshape(tensor_sample, (1, -1))

# predict
model.predict(tensor_sample)
# Out:
# 1/1 [==============================] - 0s 257ms/step
# array([[ 4.8843484,  4.905523 , -4.667286 ]], dtype=float32)
